# %% [markdown]
# # flask-googlemaps

# %%
from flask import Flask
from flask_googlemaps import GoogleMaps

app = Flask(__name__)

# you can set key as config
app.config['GOOGLEMAPS_KEY'] = "8JZ7i18MjFuM35dJHq70n3Hx4"

# Initialize the extension
GoogleMaps(app)

# you can also pass the key here if you prefer
GoogleMaps(app, key="8JZ7i18MjFuM35dJHq70n3Hx4")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-1-f97ed98de03c> in <module>
#      11
#      12 # you can also pass the key here if you prefer
# ---> 13 GoogleMaps(app, key="8JZ7i18MjFuM35dJHq70n3Hx4")
#
# ~\Anaconda3\lib\site-packages\flask_googlemaps\__init__.py in __init__(self, app, **kwargs)
#     787         self.key = kwargs.get('key')
#     788         if app:
# --> 789             self.init_app(app)
#     790
#     791     def init_app(self, app):
#
# ~\Anaconda3\lib\site-packages\flask_googlemaps\__init__.py in init_app(self, app)
#     792         if self.key:
#     793             app.config['GOOGLEMAPS_KEY'] = self.key
# --> 794         self.register_blueprint(app)
#     795         app.add_template_filter(googlemap_html)
#     796         app.add_template_filter(googlemap_js)
#
# ~\Anaconda3\lib\site-packages\flask_googlemaps\__init__.py in register_blueprint(self, app)
#     807             "googlemaps", __name__, template_folder="templates"
#     808         )
# --> 809         app.register_blueprint(module)
#     810         return module
#
# ~\Anaconda3\lib\site-packages\flask\app.py in wrapper_func(self, *args, **kwargs)
#      96                 "before the application starts serving requests."
#      97             )
# ---> 98         return f(self, *args, **kwargs)
#      99
#     100     return update_wrapper(wrapper_func, f)
#
# ~\Anaconda3\lib\site-packages\flask\app.py in register_blueprint(self, blueprint, **options)
#    1158                 ' share the same name "%s". Blueprints that are created on the'
#    1159                 " fly need unique names."
# -> 1160                 % (blueprint, self.blueprints[blueprint.name], blueprint.name)
#    1161             )
#    1162         else:
#
# AssertionError: A name collision occurred between blueprints <flask.blueprints.Blueprint object at 0x00000202DB02C668> and <flask.blueprints.Blueprint object at 0x00000202DB02C400>. Both share the same name "googlemaps". Blueprints that are created on the fly need unique names.

# %%
from flask import Flask, render_template
from flask_googlemaps import GoogleMaps
from flask_googlemaps import Map

app = Flask(__name__, template_folder=".")
GoogleMaps(app)

@app.route("/")
def mapview():
    # creating a map in the view
    mymap = Map(
        identifier="view-side",
        lat=37.4419,
        lng=-122.1419,
        markers=[(37.4419, -122.1419)]
    )
    sndmap = Map(
        identifier="sndmap",
        lat=37.4419,
        lng=-122.1419,
        markers=[
          {
             'icon': 'http://maps.google.com/mapfiles/ms/icons/green-dot.png',
             'lat': 37.4419,
             'lng': -122.1419,
             'infobox': "<b>Hello World</b>"
          },
          {
             'icon': 'http://maps.google.com/mapfiles/ms/icons/blue-dot.png',
             'lat': 37.4300,
             'lng': -122.1400,
             'infobox': "<b>Hello World from other place</b>"
          }
        ]
    )
    return render_template('example.html', mymap=mymap, sndmap=sndmap)

#

# %%
app.run(debug=True)

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../../data/pueblos.csv", sep=";")

# %%
data
# Out:
#       Comunidad          Provincia  Población   Latitud  Longitud    Altitud  \
# 0     Andalucía            Almería       Abla  37.14114 -2.780104  871.16840
# 1     Andalucía            Almería   Abrucena  37.13305 -2.797098  976.93870
# 2     Andalucía            Almería       Adra  36.74807 -3.022522   10.97898
# 3     Andalucía            Almería  Albánchez  37.28710 -2.181163  481.31230
# 4     Andalucía            Almería  Alboloduy  37.03319 -2.621750  388.43460
# ...         ...                ...        ...       ...       ...        ...
# 8104   Valencia  Valencia/València     Xeresa  39.00910 -0.217992   34.05847
# 8105   Valencia  Valencia/València  Xirivella  39.46669 -0.427794   35.01973
# 8106   Valencia  Valencia/València     Yátova  39.38500 -0.808174  441.81140
# 8107   Valencia  Valencia/València  Yesa (La)  39.49916 -0.426125   52.28455
# 8108   Valencia  Valencia/València      Zarra  39.09138 -1.075068  576.03660
#
#       Habitantes  Hombres  Mujeres
# 0           1504      783      721
# 1           1341      682      659
# 2          24373    12338    12035
# 3            815      422      393
# 4            674      334      340
# ...          ...      ...      ...
# 8104        2221     1124     1097
# 8105       30691    15474    15217
# 8106        2199     1140     1059
# 8107         260      141      119
# 8108         551      302      249
#
# [8109 rows x 9 columns]

# %%
from flask import Flask

import folium

app = Flask(__name__)


@app.route('/')
def index():
    start_coords = (46.9540700, 142.7360300)
    folium_map = folium.Map(location=start_coords, zoom_start=14)
    return folium_map._repr_html_()

# %%
app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with windowsapi reloader
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
